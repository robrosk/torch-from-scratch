# %%
import sys, os
import numpy as np
from math import prod

sys.path.insert(0, os.path.abspath("../src"))

from mini_torch.stats import sample_mean, center, sample_variance, sample_std, cov

# %%
X = np.array([[1, 2, 3], [4, 5, 6]])

# %%
X
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
X_mean = sample_mean(X, axis=1, keepdims=True)

# %%
X_mean
# Out:
# array([[2.],
#        [5.]])

# %%
center(X, axis=1)
# Out:
# array([[-1.,  0.,  1.],
#        [-1.,  0.,  1.]])

# %%
X - X_mean == center(X, axis=1)
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True]])

# %%
X, X_mean, X - X_mean
# Out:
# (array([[1, 2, 3],
#         [4, 5, 6]]),
#  array([[2.],
#         [5.]]),
#  array([[-1.,  0.,  1.],
#         [-1.,  0.,  1.]]))

# %%
sample_variance(X, axis=1, keepdims=False)
# Out:
# array([1., 1.])

# %%
sample_std(X, axis=1, keepdims=False)
# Out:
# array([1., 1.])

# %%
Y = np.array([[1, 2, 3], [4, 5, 6]])
cov(X, Y, rowvar=False, correction=0)
# Out:
# array([[2.25, 2.25, 2.25],
#        [2.25, 2.25, 2.25],
#        [2.25, 2.25, 2.25]])
