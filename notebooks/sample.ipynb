# %%
import sys, os
import numpy as np

sys.path.insert(0, os.path.abspath("../src"))

from mini_torch.stats import sample_mean

# %%
X = np.array([[1, 2, 3], [4, 5, 6]])

# %%
X
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
X_mean = sample_mean(X, axis=1, keepdims=False)

# %%
X_mean
# Out:
# array([2., 5.])
